# %%
import pandas as pd
from collections import defaultdict

    

file = pd.read_csv('cos_3.5.tsv', delimiter='\t', header=None, skiprows=1) 
df = pd.DataFrame(file)

Track = df[0].tolist()
Artist = df[1].tolist()
Lyrics = df[2].tolist()
Date = df[3].tolist()
SimK1 = df[11].tolist()
SimK2 = df[12].tolist()
SimK3 = df[13].tolist()
SimL1 = df[14].tolist()
SimL2 = df[15].tolist()
SimL3 = df[16].tolist()

threk1 = []
threk2 = []
threk3 = []
threl1 = []
threl2 = []
threl3 = []

k1_fmy = 0
k1_fmn = 0
k1_amy = 0
k1_amn = 0
k1_smy = 0
k1_smn = 0
k1_diy = 0
k1_din = 0

        
for n in SimK1:
    fn = float(n)
    if fn == 1:
        threk1.append('Perfect Match')
    elif 0.81 <= fn <= 1:
        threk1.append('Almost Match')
    elif 0.61 <= fn <= 0.8:
        threk1.append('Substantial Match')
    elif fn <= 0.6:
        threk1.append('Different Interpretation')
        
for n in SimK2:
    fn = float(n)
    if fn == 1:
        threk2.append('Perfect Match')
    elif 0.81 <= fn <= 1:
        threk2.append('Almost Match')
    elif 0.61 <= fn <= 0.8:
        threk2.append('Substantial Match')
    elif fn <= 0.6:
        threk2.append('Different Interpretation')
        
for n in SimK3:
    fn = float(n)
    if fn == 1:
        threk3.append('Perfect Match')
    elif 0.81 <= fn <= 1:
        threk3.append('Almost Match')
    elif 0.61 <= fn <= 0.8:
        threk3.append('Substantial Match')
    elif fn <= 0.6:
        threk3.append('Different Interpretation')
        

for n in SimL1:
    fn = float(n)
    if fn == 1:
        threl1.append('Perfect Match')
    elif 0.81 <= fn <= 1:
        threl1.append('Almost Match')
    elif 0.61 <= fn <= 0.8:
        threl1.append('Substantial Match')
    elif fn <= 0.6:
        threl1.append('Different Interpretation')
        
        
for n in SimL2:
    fn = float(n)
    if fn == 1:
        threl2.append('Perfect Match')
    elif 0.81 <= fn <= 1:
        threl2.append('Almost Match')
    elif 0.61 <= fn <= 0.8:
        threl2.append('Substantial Match')
    elif fn <= 0.6:
        threl2.append('Different Interpretation')
        
        
for n in SimL3:
    fn = float(n)
    if fn == 1:
        threl3.append('Perfect Match')
    elif 0.81 <= fn <= 1:
        threl3.append('Almost Match')
    elif 0.61 <= fn <= 0.8:
        threl3.append('Substantial Match')
    elif fn <= 0.6:
        threl3.append('Different Interpretation')
        
        
dict = {'Track': Track, 'Artist': Artist,'Lyrics': Lyrics, 'Date': Date, 'SimK1': SimK1, 'SimK1': SimK2,
                            'SimK3': SimK3, 'SimL1': SimL1, 'SimL2': SimL2, 'SimL3': SimL3} 

df = pd.DataFrame(dict)
df['Thre K1'] = pd.Series(threk1)
df['Thre K2'] = pd.Series(threk2)
df['Thre K3'] = pd.Series(threk3)
df['Thre L1'] = pd.Series(threl1)
df['Thre L2'] = pd.Series(threl2)
df['Thre L3'] = pd.Series(threl3)


#print(df)
df.to_csv('Thresholds GPT3.tsv',sep='\t', index = False) 

#SEPARATING POST-PRE 2-21
    
k1_pmy = 0
k1_pmn = 0
k1_amy = 0
k1_amn = 0
k1_smy = 0
k1_smn = 0
k1_diy = 0
k1_din = 0

k2_pmy = 0
k2_pmn = 0
k2_amy = 0
k2_amn = 0
k2_smy = 0
k2_smn = 0
k2_diy = 0
k2_din = 0

k3_pmy = 0
k3_pmn = 0
k3_amy = 0
k3_amn = 0
k3_smy = 0
k3_smn = 0
k3_diy = 0
k3_din = 0

l1_pmy = 0
l1_pmn = 0
l1_amy = 0
l1_amn = 0
l1_smy = 0
l1_smn = 0
l1_diy = 0
l1_din = 0

l2_pmy = 0
l2_pmn = 0
l2_amy = 0
l2_amn = 0
l2_smy = 0
l2_smn = 0
l2_diy = 0
l2_din = 0

l3_pmy = 0
l3_pmn = 0
l3_amy = 0
l3_amn = 0
l3_smy = 0
l3_smn = 0
l3_diy = 0
l3_din = 0



for a, b in zip(Date, threk1):
    if a == 'Yes' and b == 'Perfect Match':
        k1_pmy += 1
    if a == 'No' and b == 'Perfect Match':
        k1_pmn += 1
    if a == 'Yes' and b == 'Almost Match':
        k1_amy += 1
    if a == 'No' and b == 'Almost Match':
        k1_amn += 1
    if a == 'Yes' and b == 'Substantial Match':
        k1_smy += 1
    if a == 'No' and b == 'Substantial Match':
        k1_smn += 1
    if a == 'Yes' and b == 'Different Interpretation':
        k1_diy += 1
    if a == 'No' and b == 'Different Interpretation':
        k1_din += 1
        
for a, b in zip(Date, threk2):
    if a == 'Yes' and b == 'Perfect Match':
        k2_pmy += 1
    if a == 'No' and b == 'Perfect Match':
        k2_pmn += 1
    if a == 'Yes' and b == 'Almost Match':
        k2_amy += 1
    if a == 'No' and b == 'Almost Match':
        k2_amn += 1
    if a == 'Yes' and b == 'Substantial Match':
        k2_smy += 1
    if a == 'No' and b == 'Substantial Match':
        k2_smn += 1
    if a == 'Yes' and b == 'Different Interpretation':
        k2_diy += 1
    if a == 'No' and b == 'Different Interpretation':
        k2_din += 1
        
for a, b in zip(Date, threk3):
    if a == 'Yes' and b == 'Perfect Match':
        k3_pmy += 1
    if a == 'No' and b == 'Perfect Match':
        k3_pmn += 1
    if a == 'Yes' and b == 'Almost Match':
        k3_amy += 1
    if a == 'No' and b == 'Almost Match':
        k3_amn += 1
    if a == 'Yes' and b == 'Substantial Match':
        k3_smy += 1
    if a == 'No' and b == 'Substantial Match':
        k3_smn += 1
    if a == 'Yes' and b == 'Different Interpretation':
        k3_diy += 1
    if a == 'No' and b == 'Different Interpretation':
        k3_din += 1

    
for a, b in zip(Date, threl1):
    if a == 'Yes' and b == 'Perfect Match':
        l1_pmy += 1
    if a == 'No' and b == 'Perfect Match':
        l1_pmn += 1
    if a == 'Yes' and b == 'Almost Match':
        l1_amy += 1
    if a == 'No' and b == 'Almost Match':
        l1_amn += 1
    if a == 'Yes' and b == 'Substantial Match':
        l1_smy += 1
    if a == 'No' and b == 'Substantial Match':
        l1_smn += 1
    if a == 'Yes' and b == 'Different Interpretation':
        l1_diy += 1
    if a == 'No' and b == 'Different Interpretation':
        l1_din += 1
        

for a, b in zip(Date, threl2):
    if a == 'Yes' and b == 'Perfect Match':
        l2_pmy += 1
    if a == 'No' and b == 'Perfect Match':
        l2_pmn += 1
    if a == 'Yes' and b == 'Almost Match':
        l2_amy += 1
    if a == 'No' and b == 'Almost Match':
        l2_amn += 1
    if a == 'Yes' and b == 'Substantial Match':
        l2_smy += 1
    if a == 'No' and b == 'Substantial Match':
        l2_smn += 1
    if a == 'Yes' and b == 'Different Interpretation':
        l2_diy += 1
    if a == 'No' and b == 'Different Interpretation':
        l2_din += 1
        
        
for a, b in zip(Date, threl3):
    if a == 'Yes' and b == 'Perfect Match':
        l3_pmy += 1
    if a == 'No' and b == 'Perfect Match':
        l3_pmn += 1
    if a == 'Yes' and b == 'Almost Match':
        l3_amy += 1
    if a == 'No' and b == 'Almost Match':
        l3_amn += 1
    if a == 'Yes' and b == 'Substantial Match':
        l3_smy += 1
    if a == 'No' and b == 'Substantial Match':
        l3_smn += 1
    if a == 'Yes' and b == 'Different Interpretation':
        l3_diy += 1
    if a == 'No' and b == 'Different Interpretation':
        l3_din += 1
    
sims_years = defaultdict()

sims_years = {}
sims_years['Knowledge 1'] = {}
sims_years['Knowledge 1']['Perfect Match'] = {}
sims_years['Knowledge 1']['Perfect Match']['Pre-2021'] = k1_pmy
sims_years['Knowledge 1']['Perfect Match']['Post-2021'] = k1_pmn
sims_years['Knowledge 1']['Almost Match'] = {}
sims_years['Knowledge 1']['Almost Match']['Pre-2021'] = k1_amy
sims_years['Knowledge 1']['Almost Match']['Post-2021'] = k1_amn
sims_years['Knowledge 1']['Substantial Match'] = {}
sims_years['Knowledge 1']['Substantial Match']['Pre-2021'] = k1_smy
sims_years['Knowledge 1']['Substantial Match']['Post-2021'] = k1_smn
sims_years['Knowledge 1']['Different Interpretation'] = {}
sims_years['Knowledge 1']['Different Interpretation']['Pre-2021'] = k1_diy
sims_years['Knowledge 1']['Different Interpretation']['Post-2021'] = k1_din
sims_years['Knowledge 2'] = {}
sims_years['Knowledge 2']['Perfect Match'] = {}
sims_years['Knowledge 2']['Perfect Match']['Pre-2021'] = k2_pmy
sims_years['Knowledge 2']['Perfect Match']['Post-2021'] = k2_pmn
sims_years['Knowledge 2']['Almost Match'] = {}
sims_years['Knowledge 2']['Almost Match']['Pre-2021'] = k2_amy
sims_years['Knowledge 2']['Almost Match']['Post-2021'] = k2_amn
sims_years['Knowledge 2']['Substantial Match'] = {}
sims_years['Knowledge 2']['Substantial Match']['Pre-2021'] = k2_smy
sims_years['Knowledge 2']['Substantial Match']['Post-2021'] = k2_smn
sims_years['Knowledge 2']['Different Interpretation'] = {}
sims_years['Knowledge 2']['Different Interpretation']['Pre-2021'] = k2_diy
sims_years['Knowledge 2']['Different Interpretation']['Post-2021'] = k2_din
sims_years['Knowledge 3'] = {}
sims_years['Knowledge 3']['Perfect Match'] = {}
sims_years['Knowledge 3']['Perfect Match']['Pre-2021'] = k3_pmy
sims_years['Knowledge 3']['Perfect Match']['Post-2021'] = k3_pmn
sims_years['Knowledge 3']['Almost Match'] = {}
sims_years['Knowledge 3']['Almost Match']['Pre-2021'] = k3_amy
sims_years['Knowledge 3']['Almost Match']['Post-2021'] = k3_amn
sims_years['Knowledge 3']['Substantial Match'] = {}
sims_years['Knowledge 3']['Substantial Match']['Pre-2021'] = k3_smy
sims_years['Knowledge 3']['Substantial Match']['Post-2021'] = k3_smn
sims_years['Knowledge 3']['Different Interpretation'] = {}
sims_years['Knowledge 3']['Different Interpretation']['Pre-2021'] = k3_diy
sims_years['Knowledge 3']['Different Interpretation']['Post-2021'] = k3_din
sims_years['Lyrics 1'] = {}
sims_years['Lyrics 1']['Perfect Match'] = {}
sims_years['Lyrics 1']['Perfect Match']['Pre-2021'] = l1_pmy
sims_years['Lyrics 1']['Perfect Match']['Post-2021'] = l1_pmn
sims_years['Lyrics 1']['Almost Match'] = {}
sims_years['Lyrics 1']['Almost Match']['Pre-2021'] = l1_amy
sims_years['Lyrics 1']['Almost Match']['Post-2021'] = l1_amn
sims_years['Lyrics 1']['Substantial Match'] = {}
sims_years['Lyrics 1']['Substantial Match']['Pre-2021'] = l1_smy
sims_years['Lyrics 1']['Substantial Match']['Post-2021'] = l1_smn
sims_years['Lyrics 1']['Different Interpretation'] = {}
sims_years['Lyrics 1']['Different Interpretation']['Pre-2021'] = l1_diy
sims_years['Lyrics 1']['Different Interpretation']['Post-2021'] = l1_din
sims_years['Lyrics 2'] = {}
sims_years['Lyrics 2']['Perfect Match'] = {}
sims_years['Lyrics 2']['Perfect Match']['Pre-2021'] = l2_pmy
sims_years['Lyrics 2']['Perfect Match']['Post-2021'] = l2_pmn
sims_years['Lyrics 2']['Almost Match'] = {}
sims_years['Lyrics 2']['Almost Match']['Pre-2021'] = l2_amy
sims_years['Lyrics 2']['Almost Match']['Post-2021'] = l2_amn
sims_years['Lyrics 2']['Substantial Match'] = {}
sims_years['Lyrics 2']['Substantial Match']['Pre-2021'] = l2_smy
sims_years['Lyrics 2']['Substantial Match']['Post-2021'] = l2_smn
sims_years['Lyrics 2']['Different Interpretation'] = {}
sims_years['Lyrics 2']['Different Interpretation']['Pre-2021'] = l2_diy
sims_years['Lyrics 2']['Different Interpretation']['Post-2021'] = l2_din
sims_years['Lyrics 3'] = {}
sims_years['Lyrics 3']['Perfect Match'] = {}
sims_years['Lyrics 3']['Perfect Match']['Pre-2021'] = l3_pmy
sims_years['Lyrics 3']['Perfect Match']['Post-2021'] = l3_pmn
sims_years['Lyrics 3']['Almost Match'] = {}
sims_years['Lyrics 3']['Almost Match']['Pre-2021'] = l3_amy
sims_years['Lyrics 3']['Almost Match']['Post-2021'] = l3_amn
sims_years['Lyrics 3']['Substantial Match'] = {}
sims_years['Lyrics 3']['Substantial Match']['Pre-2021'] = l3_smy
sims_years['Lyrics 3']['Substantial Match']['Post-2021'] = l3_smn
sims_years['Lyrics 3']['Different Interpretation'] = {}
sims_years['Lyrics 3']['Different Interpretation']['Pre-2021'] = l3_diy
sims_years['Lyrics 3']['Different Interpretation']['Post-2021'] = l3_din

print(sims_years)

sims_pddf = pd.DataFrame.from_dict({(i,j): sims_years[i][j]
                                              for i in sims_years.keys()
                                              for j in sims_years[i].keys()},
                                             orient='index')
    
print(sims_pddf)
# Out:
# {'Knowledge 1': {'Perfect Match': {'Pre-2021': 27, 'Post-2021': 20}, 'Almost Match': {'Pre-2021': 0, 'Post-2021': 0}, 'Substantial Match': {'Pre-2021': 2, 'Post-2021': 1}, 'Different Interpretation': {'Pre-2021': 21, 'Post-2021': 29}}, 'Knowledge 2': {'Perfect Match': {'Pre-2021': 10, 'Post-2021': 6}, 'Almost Match': {'Pre-2021': 0, 'Post-2021': 0}, 'Substantial Match': {'Pre-2021': 4, 'Post-2021': 6}, 'Different Interpretation': {'Pre-2021': 36, 'Post-2021': 38}}, 'Knowledge 3': {'Perfect Match': {'Pre-2021': 5, 'Post-2021': 1}, 'Almost Match': {'Pre-2021': 0, 'Post-2021': 0}, 'Substantial Match': {'Pre-2021': 3, 'Post-2021': 4}, 'Different Interpretation': {'Pre-2021': 42, 'Post-2021': 45}}, 'Lyrics 1': {'Perfect Match': {'Pre-2021': 28, 'Post-2021': 26}, 'Almost Match': {'Pre-2021': 0, 'Post-2021': 0}, 'Substantial Match': {'Pre-2021': 1, 'Post-2021': 5}, 'Different Interpretation': {'Pre-2021': 21, 'Post-2021': 19}}, 'Lyrics 2': {'Perfect Match': {'Pre-2021': 26, 'Post-2021': 23}
# ...

# %%
from collections import defaultdict
  
def return_value():
    return "N/A"
      

sims_years = defaultdict()

sims_years = {}
    sims_years['Perfect Match'] = {}
    sims_years['Perfect Match']['Pre-2021'] = pmy
    sims_years['Perfect Match']['Post-2021'] = pmn
    sims_years['Almost Match'] = {}
    sims_years['Almost Match']['Pre-2021'] = amy
    sims_years['Almost Match']['Post-2021'] = amn
    sims_years['Substantial Match'] = {}
    sims_years['Substantial Match']['Pre-2021'] = smy
    sims_years['Substantial Match']['Post-2021'] = smn
    sims_years['Different Interpretation'] = {}
    sims_years['Different Interpretation']['Pre-2021'] = diy
    sims_years['Different Interpretation']['Post-2021'] = dnn
